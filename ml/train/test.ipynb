# %%
import os
import pickle
import time
from pathlib import Path

import cv2
import numpy as np
import pandas as pd
import torch
import torchvision.models as models
from sklearn.preprocessing import LabelEncoder
from torch import nn
from torch.utils.data import DataLoader, Dataset
from torchvision.transforms import v2 as transforms

labels1 = pd.read_csv('synth3/labels.csv')
labels1['filename']=labels1['filename'].str.replace('/home/roman/gagarin/data_generation/data/final_dataset1', 'synth3')
labels2 = pd.read_csv('synth3/labels2.csv')
labels2['filename']=labels2['filename'].str.replace('/home/roman/gagarin/data_generation/data/final_dataset', 'synth3')

labels = pd.concat([labels1, labels2]).sample(frac=1.0)

le = LabelEncoder()
labels['anomaly'] = le.fit_transform(labels['anomaly'])

# %%
class VideoDataset(Dataset):
    def __init__(self, labels, transform=None):
        """
        Args:
            labels (DataFrame): DataFrame с двумя колонками, первая с путями, вторая с метками.
            transform (callable, optional): Необязательные трансформации для применения к каждому кадру.
        """
        self.labels = labels
        self.transform = transform
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        filename, label = self.labels.iloc[idx]
        path = filename
        target_path = path.replace('bin', 'h264')

        # Копирование файла с изменением формата
        if not Path(target_path).exists():
            with open(path, 'rb') as f:
                data = f.read()
                with open(target_path, 'wb') as f:
                    
                    f.write(data)
        
        # Чтение видео
        video = cv2.VideoCapture(target_path)
        seq = []
        cnt = 0
        while cnt < 2:
            ret, frame = video.read()
            if not ret:
                break
            
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB) 
            frame = cv2.resize(frame, (384, 384), interpolation=cv2.INTER_AREA)
            if self.transform:
                frame = self.transform(frame)
            else:
                frame = torch.from_numpy(frame)
            seq.append(frame)
            cnt += 1
        
        video.release()
        # os.remove(target_path)  
        
        seq = torch.stack(seq, dim=0)
        return seq, label

test_size = int(len(labels)*0.15)
test_list = labels[-test_size:]
train_list = labels[:-test_size]

# %%
class Model(nn.Module):
    def __init__(self, n_class=2):
        super(Model, self).__init__()
        
        self.resnet = models.resnet18(pretrained=True)
        self.resnet.fc = torch.nn.Identity()
        
        self.fc = nn.Sequential(
            nn.Linear(512, 256,),
            nn.ReLU(),
            nn.Linear(256, n_class)
        )
        
    def forward(self, x):
        batch_size, seq_size = x.shape[:2]
        x = self.resnet(x.reshape(batch_size*seq_size, 3, 224, 224))
        x = x.reshape(batch_size, seq_size, 512)
        x = x.mean(1)
        x = self.fc(x)
        return x
    
device = 'cuda'
model = Model(5).to(device)
# Out:
# /home/fromy/anaconda3/envs/env/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/fromy/anaconda3/envs/env/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
def train(dataloader, criterion, optimizer, epoch):
    model.train()
    total_acc, total_count = 0, 0
    log_interval = 1

    for idx, (data, label) in enumerate(dataloader):
        optimizer.zero_grad()
        data = data.to(device)
        label = label.to(dtype=torch.long, device=device)
        predicted_label = model(data)

        loss = criterion(predicted_label, label)
        
        loss.backward()

        optimizer.step()
        total_acc += (predicted_label.argmax(1) == label).sum().item()
        total_count += label.size(0)

        print(
            "| epoch {:3d} | {:5d}/{:5d} batches "
            "| accuracy {}".format(
                epoch, idx, len(dataloader), total_acc / total_count
            )
        )
        total_acc, total_count = 0, 0
        
def evaluate(dataloader):
    model.eval()
    total_acc, total_count = 0, 0

    with torch.no_grad():
        for idx, (data, label) in enumerate(dataloader):
            
            data, label = data.to(device), label.to(dtype=torch.long, device=device)
            predicted_label = model(data)
            total_acc += (predicted_label.argmax(1) == label).sum().item()
            total_count += label.size(0)
    return total_acc / total_count

# %%
bs = 128

transform = transforms.Compose(
                [
                    transforms.ToTensor(),
                    transforms.RandomResizedCrop(224),
                    transforms.RandomHorizontalFlip(),
                    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])
                ])

val_transform = transforms.Compose(
                [
                    transforms.ToTensor(),
                    transforms.Resize(224),
                    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])
                ])

train_dataset = VideoDataset(train_list, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=bs, shuffle=True)

test_dataset = VideoDataset(test_list, transform=val_transform)
test_loader = DataLoader(test_dataset, batch_size=bs, shuffle=True)

EPOCHS = 3 
LR = 1e-3

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters()) 
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.7)
total_accu = None

for epoch in range(1, EPOCHS + 1):
    epoch_start_time = time.time()
    train(train_loader, criterion, optimizer, epoch)
    
    accu_val = evaluate(test_loader)

    print("-" * 59)
    print(
        "| end of epoch {:3d} | time: {:5.2f}s | "
        "valid accuracy {:8.3f} ".format(
            epoch, time.time() - epoch_start_time, accu_val
        )
    )
    print("-" * 59)
    
    scheduler.step()
# Out:
# /home/fromy/anaconda3/envs/env/lib/python3.10/site-packages/torchvision/transforms/v2/_deprecated.py:43: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.
#   warnings.warn(
# /home/fromy/anaconda3/envs/env/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# | epoch   1 |     0/   96 batches | accuracy 0.4375
# | epoch   1 |     1/   96 batches | accuracy 0.828125
# | epoch   1 |     2/   96 batches | accuracy 0.8203125
# | epoch   1 |     3/   96 batches | accuracy 0.8359375
# | epoch   1 |     4/   96 batches | accuracy 0.796875
# | epoch   1 |     5/   96 batches | accuracy 0.953125
# | epoch   1 |     6/   96 batches | accuracy 0.9453125
# | epoch   1 |     7/   96 batches | accuracy 0.9140625
# | epoch   1 |     8/   96 batches | accuracy 0.875
# | epoch   1 |     9/   96 batches | accuracy 0.921875
# | epoch   1 |    10/   96 batches | accuracy 0.953125
# | epoch   1 |    11/   96 batches | accuracy 0.90625
# | epoch   1 |    12/   96 batches | accuracy 0.9296875
# | epoch   1 |    13/   96 batches | accuracy 0.90625
# | epoch   1 |    14/   96 batches | accuracy 0.9140625
# | epoch   1 |    15/   96 batches | accuracy 0.9609375
# | epoch   1 |    16/   96 batches | accuracy 0.90625
# | epoch   1 |    17/   96 batches | accuracy 0.9609375
# | epoch   1 |    18/   96 batches | accuracy 0.9375
# | epoch   1 |    19/   96 batches | accuracy 0.953125
# | epoch   1 |    20/   96 batches | accuracy 0.9296875
# | epoch   1 |    21/   96 batches | accuracy 0.984375
# | epoch   1 |    22/   96 batches | accuracy 0.984375
# | epoch   1 |    23/   96 batches | accuracy 0.9453125
# | epoch   1 |    24/   96 batches | accuracy 0.9609375
# | epoch   1 |    25/   96 batches | accuracy 0.921875
# | epoch   1 |    26/   96 batches | accuracy 0.96875
# | epoch   1 |    27/   96 batches | accuracy 0.953125
# | epoch   1 |    28/   96 batches | accuracy 0.953125
# | epoch   1 |    29/   96 batches | accuracy 0.9296875
# | epoch   1 |    30/   96 batches | accuracy 0.9140625
# | epoch   1 |    31/   96 batches | accuracy 0.9296875
# | epoch   1 |    32/   96 batches | accuracy 0.9296875
# | epoch   1 |    33/   96 batches | accuracy 0.9453125
# | epoch   1 |    34/   96 batches | accuracy 0.9453125
# | epoch   1 |    35/   96 batches | accuracy 0.9296875
# | epoch   1 |    36/   96 batches | accuracy 0.9765625
# | epoch   1 |    37/   96 batches | accuracy 0.953125
# | epoch   1 |    38/   96 batches | accuracy 0.9296875
# | epoch   1 |    39/   96 batches | accuracy 0.9765625
# | epoch   1 |    40/   96 batches | accuracy 0.984375
# | epoch   1 |    41/   96 batches | accuracy 0.96875
# | epoch   1 |    42/   96 batches | accuracy 0.921875
# | epoch   1 |    43/   96 batches | accuracy 0.921875
# | epoch   1 |    44/   96 batches | accuracy 0.9296875
# | epoch   1 |    45/   96 batches | accuracy 0.96875
# | epoch   1 |    46/   96 batches | accuracy 0.96875
# | epoch   1 |    47/   96 batches | accuracy 0.9375
# | epoch   1 |    48/   96 batches | accuracy 0.953125
# | epoch   1 |    49/   96 batches | accuracy 0.921875
# | epoch   1 |    50/   96 batches | accuracy 0.890625
# | epoch   1 |    51/   96 batches | accuracy 0.9140625
# | epoch   1 |    52/   96 batches | accuracy 0.9140625
# | epoch   1 |    53/   96 batches | accuracy 0.953125
# | epoch   1 |    54/   96 batches | accuracy 0.9765625
# | epoch   1 |    55/   96 batches | accuracy 0.9609375
# | epoch   1 |    56/   96 batches | accuracy 0.9453125
# | epoch   1 |    57/   96 batches | accuracy 0.9453125
# | epoch   1 |    58/   96 batches | accuracy 0.9296875
# | epoch   1 |    59/   96 batches | accuracy 0.921875
# | epoch   1 |    60/   96 batches | accuracy 0.953125
# | epoch   1 |    61/   96 batches | accuracy 0.953125
# | epoch   1 |    62/   96 batches | accuracy 0.953125
# | epoch   1 |    63/   96 batches | accuracy 0.9296875
# | epoch   1 |    64/   96 batches | accuracy 0.9609375
# | epoch   1 |    65/   96 batches | accuracy 0.9765625
# | epoch   1 |    66/   96 batches | accuracy 0.96875
# | epoch   1 |    67/   96 batches | accuracy 0.96875
# | epoch   1 |    68/   96 batches | accuracy 0.953125
# | epoch   1 |    69/   96 batches | accuracy 0.9921875
# | epoch   1 |    70/   96 batches | accuracy 0.9609375
# | epoch   1 |    71/   96 batches | accuracy 0.953125
# | epoch   1 |    72/   96 batches | accuracy 0.9609375
# | epoch   1 |    73/   96 batches | accuracy 0.96875
# | epoch   1 |    74/   96 batches | accuracy 0.921875
# | epoch   1 |    75/   96 batches | accuracy 0.9453125
# | epoch   1 |    76/   96 batches | accuracy 0.9609375
# | epoch   1 |    77/   96 batches | accuracy 0.9765625
# | epoch   1 |    78/   96 batches | accuracy 0.953125
# | epoch   1 |    79/   96 batches | accuracy 0.984375
# | epoch   1 |    80/   96 batches | accuracy 0.96875
# | epoch   1 |    81/   96 batches | accuracy 0.96875
# | epoch   1 |    82/   96 batches | accuracy 0.9453125
# | epoch   1 |    83/   96 batches | accuracy 0.96875
# | epoch   1 |    84/   96 batches | accuracy 0.9296875
# | epoch   1 |    85/   96 batches | accuracy 0.96875
# | epoch   1 |    86/   96 batches | accuracy 0.9609375
# | epoch   1 |    87/   96 batches | accuracy 0.9765625
# | epoch   1 |    88/   96 batches | accuracy 0.9609375
# | epoch   1 |    89/   96 batches | accuracy 0.9375
# | epoch   1 |    90/   96 batches | accuracy 0.984375
# | epoch   1 |    91/   96 batches | accuracy 0.953125
# | epoch   1 |    92/   96 batches | accuracy 0.96875
# | epoch   1 |    93/   96 batches | accuracy 0.9765625
# | epoch   1 |    94/   96 batches | accuracy 0.9453125
# | epoch   1 |    95/   96 batches | accuracy 0.9625
# -----------------------------------------------------------
# | end of epoch   1 | time: 507.54s | valid accuracy    0.951
# -----------------------------------------------------------
# | epoch   2 |     0/   96 batches | accuracy 0.9921875
# | epoch   2 |     1/   96 batches | accuracy 0.96875
# | epoch   2 |     2/   96 batches | accuracy 0.953125
# | epoch   2 |     3/   96 batches | accuracy 0.984375
# | epoch   2 |     4/   96 batches | accuracy 0.9921875
# | epoch   2 |     5/   96 batches | accuracy 0.9609375
# | epoch   2 |     6/   96 batches | accuracy 0.96875
# | epoch   2 |     7/   96 batches | accuracy 0.9609375
# | epoch   2 |     8/   96 batches | accuracy 0.984375
# | epoch   2 |     9/   96 batches | accuracy 0.9921875
# | epoch   2 |    10/   96 batches | accuracy 0.9921875
# | epoch   2 |    11/   96 batches | accuracy 0.984375
# | epoch   2 |    12/   96 batches | accuracy 0.953125
# | epoch   2 |    13/   96 batches | accuracy 0.96875
# | epoch   2 |    14/   96 batches | accuracy 0.9453125
# | epoch   2 |    15/   96 batches | accuracy 0.9453125
# | epoch   2 |    16/   96 batches | accuracy 0.953125
# | epoch   2 |    17/   96 batches | accuracy 0.9453125
# | epoch   2 |    18/   96 batches | accuracy 0.9765625
# | epoch   2 |    19/   96 batches | accuracy 0.9609375
# | epoch   2 |    20/   96 batches | accuracy 0.9765625
# | epoch   2 |    21/   96 batches | accuracy 0.96875
# | epoch   2 |    22/   96 batches | accuracy 0.9765625
# | epoch   2 |    23/   96 batches | accuracy 0.96875
# | epoch   2 |    24/   96 batches | accuracy 0.9765625
# | epoch   2 |    25/   96 batches | accuracy 0.984375
# | epoch   2 |    26/   96 batches | accuracy 0.984375
# | epoch   2 |    27/   96 batches | accuracy 0.9765625
# | epoch   2 |    28/   96 batches | accuracy 0.9765625
# | epoch   2 |    29/   96 batches | accuracy 0.96875
# | epoch   2 |    30/   96 batches | accuracy 0.96875
# | epoch   2 |    31/   96 batches | accuracy 0.9765625
# | epoch   2 |    32/   96 batches | accuracy 0.9765625
# | epoch   2 |    33/   96 batches | accuracy 0.96875
# | epoch   2 |    34/   96 batches | accuracy 0.96875
# | epoch   2 |    35/   96 batches | accuracy 0.9609375
# | epoch   2 |    36/   96 batches | accuracy 0.9765625
# | epoch   2 |    37/   96 batches | accuracy 0.9921875
# | epoch   2 |    38/   96 batches | accuracy 0.9453125
# | epoch   2 |    39/   96 batches | accuracy 0.9921875
# | epoch   2 |    40/   96 batches | accuracy 0.9609375
# | epoch   2 |    41/   96 batches | accuracy 0.953125
# | epoch   2 |    42/   96 batches | accuracy 0.984375
# | epoch   2 |    43/   96 batches | accuracy 0.953125
# | epoch   2 |    44/   96 batches | accuracy 0.9765625
# | epoch   2 |    45/   96 batches | accuracy 0.96875
# | epoch   2 |    46/   96 batches | accuracy 0.96875
# | epoch   2 |    47/   96 batches | accuracy 0.9921875
# | epoch   2 |    48/   96 batches | accuracy 0.96875
# | epoch   2 |    49/   96 batches | accuracy 0.96875
# | epoch   2 |    50/   96 batches | accuracy 0.9453125
# | epoch   2 |    51/   96 batches | accuracy 0.96875
# | epoch   2 |    52/   96 batches | accuracy 0.96875
# | epoch   2 |    53/   96 batches | accuracy 1.0
# | epoch   2 |    54/   96 batches | accuracy 0.984375
# | epoch   2 |    55/   96 batches | accuracy 0.9609375
# | epoch   2 |    56/   96 batches | accuracy 0.9765625
# | epoch   2 |    57/   96 batches | accuracy 0.9609375
# | epoch   2 |    58/   96 batches | accuracy 0.953125
# | epoch   2 |    59/   96 batches | accuracy 0.953125
# | epoch   2 |    60/   96 batches | accuracy 0.96875
# | epoch   2 |    61/   96 batches | accuracy 0.9765625
# | epoch   2 |    62/   96 batches | accuracy 0.96875
# | epoch   2 |    63/   96 batches | accuracy 0.953125
# | epoch   2 |    64/   96 batches | accuracy 1.0
# | epoch   2 |    65/   96 batches | accuracy 0.9921875
# | epoch   2 |    66/   96 batches | accuracy 0.9765625
# | epoch   2 |    67/   96 batches | accuracy 0.984375
# | epoch   2 |    68/   96 batches | accuracy 0.984375
# | epoch   2 |    69/   96 batches | accuracy 0.9921875
# | epoch   2 |    70/   96 batches | accuracy 0.9921875
# | epoch   2 |    71/   96 batches | accuracy 0.984375
# | epoch   2 |    72/   96 batches | accuracy 0.984375
# | epoch   2 |    73/   96 batches | accuracy 0.9765625
# | epoch   2 |    74/   96 batches | accuracy 0.9609375
# | epoch   2 |    75/   96 batches | accuracy 0.9921875
# | epoch   2 |    76/   96 batches | accuracy 1.0
# | epoch   2 |    77/   96 batches | accuracy 0.9765625
# | epoch   2 |    78/   96 batches | accuracy 0.9921875
# | epoch   2 |    79/   96 batches | accuracy 0.9921875
# | epoch   2 |    80/   96 batches | accuracy 0.984375
# | epoch   2 |    81/   96 batches | accuracy 0.9921875
# | epoch   2 |    82/   96 batches | accuracy 0.9609375
# | epoch   2 |    83/   96 batches | accuracy 0.9921875
# | epoch   2 |    84/   96 batches | accuracy 1.0
# | epoch   2 |    85/   96 batches | accuracy 1.0
# | epoch   2 |    86/   96 batches | accuracy 0.9609375
# | epoch   2 |    87/   96 batches | accuracy 0.9609375
# | epoch   2 |    88/   96 batches | accuracy 0.9609375
# | epoch   2 |    89/   96 batches | accuracy 0.984375
# | epoch   2 |    90/   96 batches | accuracy 0.9765625
# | epoch   2 |    91/   96 batches | accuracy 0.953125
# | epoch   2 |    92/   96 batches | accuracy 0.9765625
# | epoch   2 |    93/   96 batches | accuracy 0.9921875
# | epoch   2 |    94/   96 batches | accuracy 0.9765625
# | epoch   2 |    95/   96 batches | accuracy 0.975
# -----------------------------------------------------------
# | end of epoch   2 | time: 496.92s | valid accuracy    0.974
# -----------------------------------------------------------
# | epoch   3 |     0/   96 batches | accuracy 0.9765625
# | epoch   3 |     1/   96 batches | accuracy 0.9765625
# | epoch   3 |     2/   96 batches | accuracy 0.9609375
# | epoch   3 |     3/   96 batches | accuracy 0.96875
# | epoch   3 |     4/   96 batches | accuracy 0.9765625
# | epoch   3 |     5/   96 batches | accuracy 0.9765625
# | epoch   3 |     6/   96 batches | accuracy 0.9765625
# | epoch   3 |     7/   96 batches | accuracy 0.96875
# | epoch   3 |     8/   96 batches | accuracy 0.96875
# | epoch   3 |     9/   96 batches | accuracy 0.9765625
# | epoch   3 |    10/   96 batches | accuracy 0.9609375
# | epoch   3 |    11/   96 batches | accuracy 0.9609375
# | epoch   3 |    12/   96 batches | accuracy 0.9921875
# | epoch   3 |    13/   96 batches | accuracy 0.9609375
# | epoch   3 |    14/   96 batches | accuracy 0.9921875
# | epoch   3 |    15/   96 batches | accuracy 0.9921875
# | epoch   3 |    16/   96 batches | accuracy 0.984375
# | epoch   3 |    17/   96 batches | accuracy 0.9609375
# | epoch   3 |    18/   96 batches | accuracy 0.984375
# | epoch   3 |    19/   96 batches | accuracy 0.9765625
# | epoch   3 |    20/   96 batches | accuracy 0.9765625
# | epoch   3 |    21/   96 batches | accuracy 0.9921875
# | epoch   3 |    22/   96 batches | accuracy 0.9921875
# | epoch   3 |    23/   96 batches | accuracy 0.9921875
# | epoch   3 |    24/   96 batches | accuracy 0.984375
# | epoch   3 |    25/   96 batches | accuracy 0.984375
# | epoch   3 |    26/   96 batches | accuracy 0.9765625
# | epoch   3 |    27/   96 batches | accuracy 1.0
# | epoch   3 |    28/   96 batches | accuracy 0.984375
# | epoch   3 |    29/   96 batches | accuracy 0.9921875
# | epoch   3 |    30/   96 batches | accuracy 0.9921875
# | epoch   3 |    31/   96 batches | accuracy 0.984375
# | epoch   3 |    32/   96 batches | accuracy 1.0
# | epoch   3 |    33/   96 batches | accuracy 0.9765625
# | epoch   3 |    34/   96 batches | accuracy 0.96875
# | epoch   3 |    35/   96 batches | accuracy 1.0
# | epoch   3 |    36/   96 batches | accuracy 0.96875
# | epoch   3 |    37/   96 batches | accuracy 0.9921875
# | epoch   3 |    38/   96 batches | accuracy 0.984375
# | epoch   3 |    39/   96 batches | accuracy 0.9765625
# | epoch   3 |    40/   96 batches | accuracy 0.984375
# | epoch   3 |    41/   96 batches | accuracy 0.9921875
# | epoch   3 |    42/   96 batches | accuracy 0.984375
# | epoch   3 |    43/   96 batches | accuracy 0.9765625
# | epoch   3 |    44/   96 batches | accuracy 0.9921875
# | epoch   3 |    45/   96 batches | accuracy 0.9921875
# | epoch   3 |    46/   96 batches | accuracy 0.9921875
# | epoch   3 |    47/   96 batches | accuracy 0.9921875
# | epoch   3 |    48/   96 batches | accuracy 0.9765625
# | epoch   3 |    49/   96 batches | accuracy 0.9765625
# | epoch   3 |    50/   96 batches | accuracy 0.9921875
# | epoch   3 |    51/   96 batches | accuracy 0.9921875
# | epoch   3 |    52/   96 batches | accuracy 0.96875
# | epoch   3 |    53/   96 batches | accuracy 0.984375
# | epoch   3 |    54/   96 batches | accuracy 0.984375
# | epoch   3 |    55/   96 batches | accuracy 0.9921875
# | epoch   3 |    56/   96 batches | accuracy 0.9921875
# | epoch   3 |    57/   96 batches | accuracy 1.0
# | epoch   3 |    58/   96 batches | accuracy 0.984375
# | epoch   3 |    59/   96 batches | accuracy 0.9921875
# | epoch   3 |    60/   96 batches | accuracy 0.9765625
# | epoch   3 |    61/   96 batches | accuracy 0.9921875
# | epoch   3 |    62/   96 batches | accuracy 0.9765625
# | epoch   3 |    63/   96 batches | accuracy 0.9921875
# | epoch   3 |    64/   96 batches | accuracy 0.984375
# | epoch   3 |    65/   96 batches | accuracy 0.96875
# | epoch   3 |    66/   96 batches | accuracy 0.9921875
# | epoch   3 |    67/   96 batches | accuracy 0.9921875
# | epoch   3 |    68/   96 batches | accuracy 1.0
# | epoch   3 |    69/   96 batches | accuracy 0.9765625
# | epoch   3 |    70/   96 batches | accuracy 0.96875
# | epoch   3 |    71/   96 batches | accuracy 0.9765625
# | epoch   3 |    72/   96 batches | accuracy 0.9921875
# | epoch   3 |    73/   96 batches | accuracy 0.9765625
# | epoch   3 |    74/   96 batches | accuracy 0.9765625
# | epoch   3 |    75/   96 batches | accuracy 0.9765625
# | epoch   3 |    76/   96 batches | accuracy 1.0
# | epoch   3 |    77/   96 batches | accuracy 1.0
# | epoch   3 |    78/   96 batches | accuracy 0.9921875
# | epoch   3 |    79/   96 batches | accuracy 0.984375
# | epoch   3 |    80/   96 batches | accuracy 0.9765625
# | epoch   3 |    81/   96 batches | accuracy 0.9921875
# | epoch   3 |    82/   96 batches | accuracy 0.984375
# | epoch   3 |    83/   96 batches | accuracy 0.9921875
# | epoch   3 |    84/   96 batches | accuracy 1.0
# | epoch   3 |    85/   96 batches | accuracy 0.9921875
# | epoch   3 |    86/   96 batches | accuracy 0.9765625
# | epoch   3 |    87/   96 batches | accuracy 0.96875
# | epoch   3 |    88/   96 batches | accuracy 0.9921875
# | epoch   3 |    89/   96 batches | accuracy 1.0
# | epoch   3 |    90/   96 batches | accuracy 0.984375
# | epoch   3 |    91/   96 batches | accuracy 0.9765625
# | epoch   3 |    92/   96 batches | accuracy 0.9765625
# | epoch   3 |    93/   96 batches | accuracy 0.9765625
# | epoch   3 |    94/   96 batches | accuracy 0.9765625
# | epoch   3 |    95/   96 batches | accuracy 0.9625
# -----------------------------------------------------------
# | end of epoch   3 | time: 488.68s | valid accuracy    0.983
# -----------------------------------------------------------

# %%
with open('resnet/model.pt', 'wb') as f:
    torch.save(model.state_dict(), f)
    

with open("resnet/le.pkl", "wb") as f:
    pickle.dump(le, f)
